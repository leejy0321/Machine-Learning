# %%
import numpy as np
import pandas as pd
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-543ea08b-5443-4949-8ec3-66c8412f001f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-543ea08b-5443-4949-8ec3-66c8412f001f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('social.csv')
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
mapping_dict = {'Male' : 1,
                'Female' : 2}

df['Gender'] = df['Gender'].apply(lambda x : mapping_dict[x])
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510       1   19            19000          0
# 1    15810944       1   35            20000          0
# 2    15668575       2   26            43000          0
# 3    15603246       2   27            57000          0
# 4    15804002       1   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863       2   46            41000          1
# 396  15706071       1   51            23000          1
# 397  15654296       2   50            20000          1
# 398  15755018       1   36            33000          0
# 399  15594041       2   49            36000          1
#
# [400 rows x 5 columns]

# %%
X = df[['Gender', 'Age', 'EstimatedSalary']]
y = df['Purchased']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

SVM = SVC()
SVMclf = AdaBoostClassifier(base_estimator = SVM, algorithm="SAMME")
SVMclf.fit(X_train, y_train)
SVMpred = SVMclf.predict(X_test)

print("SVM adaboost accuracy: ", accuracy_score(y_test, SVMpred))
# Out:
# SVM adaboost accuracy:  0.675

# %%
pip install hep_ml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from hep_ml.nnet import MLPClassifier

ANN = MLPClassifier()
ANNclf = AdaBoostClassifier(base_estimator = ANN)
ANNclf.fit(X_train, y_train)
ANNpred = ANNclf.predict(X_test)

print("ANN adaboost accuracy: ", accuracy_score(y_test, ANNpred))
# Out:
# ANN adaboost accuracy:  0.875
